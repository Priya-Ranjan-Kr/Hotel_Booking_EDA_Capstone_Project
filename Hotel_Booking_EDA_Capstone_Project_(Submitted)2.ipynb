# %% [markdown]
# ### **Project Name   :- EDA-Hotel Booking Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# #### **Cohort**           - Rome
#
# ##### **Member**          - Priya Ranjan Kr.

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The purpose of this project is to perform an exploratory data analysis (EDA) on a dataset of hotel bookings. The dataset contains information on bookings made at two hotels over a period of time, including information on the guests, the booking, and the hotel itself. The dataset also includes information on cancellations and no-shows.
#
# The goal of the EDA is to gain insights into the data and answer questions such as:
#
# Which type of hotel is mostly prefered by the guests?
# How does lead time for booking vary across different arrival years, and what is the cancellation trend associated with it?
# From which country the most guests are coming?
# Analyze the distribution of preferred meal types among hotel guests.
# ADR relationship with total number of people
# Which year had the highest bookings?
# Which distribution channel contributed more to adr in order to increase the the income?
# ADR across the different month.
# Which distribution channel has the higest cancellation rate?
# Which distribution channel has the higest count of repeated guest?
# Analyze the distribution of market segments and distribution channels in hotel bookings.
# Analyze the distribution of guests with babies across different hotel types and their booking cancellation rates.
# Analyze the distribution of hotel arrivals by year and month.
#
# The EDA will begin with a data cleaning process, where missing or erroneous data will be identified and addressed. The data will then be explored through a variety of visualizations, including scatter plots, histograms, and heatmaps, to identify patterns and relationships in the data.
#
# The final deliverables for this project will include a report summarizing the findings, as well as visualizations and code used in the EDA. This report will be useful for stakeholders such as hotel managers, who can use the insights gained to improve their operations and make data-driven decisions.

# %% [markdown]
# # **GitHub Link -** - https://github.com/Priya-Ranjan-Kr/Hotel_Booking_EDA_Capstone_Project

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ### The hospitality industry is highly competitive, and hotels need to continuously improve their services to stay ahead of the competition. One way to achieve this is by analyzing customer data and behavior to identify trends and patterns that can be used to improve customer satisfaction and increase revenue.
# ### The problem we aim to solve in this project is to analyze the data of hotel bookings and cancellations to identify factors that affect customer bookings and cancellations. We will use exploratory data analysis (EDA) techniques to identify patterns in the data that can help hotels optimize their operations and improve customer satisfaction.
#
# ### The goal of this project is to provide insights that can be used to improve hotel booking systems, enhance the customer experience, and increase revenue. We will explore the data to answer questions such as: What are the most common reasons for booking cancellations? What factors influence customers to book a particular hotel? How can hotels use this information to improve their services and attract more customers?
#
# ### The insights gained from this analysis can help hotels optimize their pricing, improve customer service, and offer personalized experiences to their customers. Additionally, it can provide valuable information to other stakeholders such as travel agencies, online travel agents, and hotel industry researchers.

# %% [markdown]
# ### **Define Your Business Objective?**

# %% [markdown]
# ### The business objective of the hotel booking analysis is to provide actionable insights to the hotel industry stakeholders, such as hotel managers, marketers, and other decision-makers, that can help them improve their operations and enhance the customer experience. Specifically, the analysis aims to:
#
# ### 1.Identify the factors that affect hotel booking and cancellation rates
#
# ### 2.Discover patterns in the data that can help optimize pricing strategies and occupancy rates
#
# ### 3.Analyze customer preferences and behavior to personalize hotel offerings and enhance customer satisfaction
#
# ### 4.Provide insights into the competitive landscape and help hotels differentiate themselves from their competitors
#
# ### 5.Optimize marketing strategies to attract more customers and increase revenue.
#
# ### By achieving these objectives, the hotel industry stakeholders can make informed decisions and take action to improve their operations, increase revenue, and provide a better customer experience. Ultimately, the goal is to use the insights gained from the analysis to stay competitive in the market and achieve long-term success.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing neccesary libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
df=pd.read_csv("/content/drive/MyDrive/Hotel Booking.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# creating a copy of our dataset
df_copy=df.copy()

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 31994

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <Axes: >

# %% [markdown]
# So we Have Null values in columns- Company, agent, Country,children.
# 1. for agent I will fill the Missing values with 0
# 2. for country I will fill Missing values with boject 'Others'. ( assuming while collecting data country was not found so user selected the 'Others' option.)
# 3. AS the count of missing values in Children Column is only 4, so we can replace with 0 considering no childrens.
# 4. and the variable company had null values greater than 50%, so removed it.

# %%
# Filling/replacing null values with 0.
null_columns=['agent','children']
for col in null_columns:
  df[col].fillna(0,inplace=True)


# Replacing NA values with 'others'
df['country'].fillna('others',inplace=True)

# %%
# Dropping variable having more than 50% null values
# df.drop(columns='company', axis  = 1,inplace=True)
df.drop(['company'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (87396, 31)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (87396, 31)

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
all_columns=df.columns
all_columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe numerical data
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# - hotel:- Name of hotel ( City or Resort)
# - is_canceled:- Whether the booking is canceled or not (0 for no canceled and 1 for canceled)
# - lead_time:- time (in days) between booking transaction and actual arrival.
# - arrival_date_year:- Year of arrival
# - arrival_date_month:- month of arrival
# - arrival_date_week_number:- week number of arrival date.
# - arrival_date_day_of_month:- Day of month of arrival date
# - stays_in_weekend_nights:- No. of weekend nights spent in a hotel
# - stays_in_week_nights:- No. of weeknights spent in a hotel
# - adults:- No. of adults in single booking record.
# - children:- No. of children in single booking record.
# - babies:- No. of babies in single booking record.
# - meal:- Type of meal chosen
# - country:- Country of origin of customers (as mentioned by them)
# - market_segment:- What segment via booking was made and for what purpose.
# - distribution_channel:- Via which medium booking was made.
# - is_repeated_guest:- Whether the customer has made any booking before(0 for No and 1 for Yes)
# - previous_cancellations:- No. of previous canceled bookings.
# - previous_bookings_not_canceled:- No. of previous non-canceled bookings.
# - reserved_room_type:- Room type reserved by a customer.
# - assigned_room_type:- Room type assigned to the customer.
# - booking_changes:- No. of booking changes done by customers
# - deposit_type:- Type of deposit at the time of making a booking (No deposit/ Refundable/ No refund)
# - agent:- Id of agent for booking
# - company:- Id of the company making a booking
# - days_in_waiting_list:- No. of days on waiting list.
# - customer_type:- Type of customer(Transient, Group, etc.)
# - adr:- Average Daily Rate.
# - required_car_parking_spaces:- No. of car parking asked in booking
# - total_of_special_requests:- total no. of special request.
# - reservation_status:- Whether a customer has checked out or canceled,or not showed
# - reservation_status_date:- Date of making reservation status.

# %% [markdown]
# ## `The dataset have 31 variables (Continuous and Categorical) with one identified dependent variable (categorical), which is 'is_cancelled.`

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# lets add  new column

df['total_people'] = df['adults'] + df['babies'] + df['children']

# %% [markdown]
# to find ADR relationship with total number of people.
# we add new column of total_people by aggragating other columns

# %%
df['is_canceled'].value_counts()
# Out:
# is_canceled
# 0    63371
# 1    24025
# Name: count, dtype: int64

# %% [markdown]
#  **24025 bookings were canceled**

# %% [markdown]
# ### **Country wise bookings**

# %%
df.country.value_counts(normalize=True)
# Out:
# country
# PRT    0.314122
# GBR    0.119376
# FRA    0.101114
# ESP    0.082979
# DEU    0.061639
#          ...
# MMR    0.000011
# BFA    0.000011
# CYM    0.000011
# MLI    0.000011
# KHM    0.000011
# Name: proportion, Length: 178, dtype: float64

# %% [markdown]
#  **Around 31% of all bookings were booked from Portugal followed by Great Britain(11%) & France(10%)**

# %% [markdown]
# ####**Relative distribution of arrivals across different months.**

# %%
df.arrival_date_month.value_counts(normalize=True)
# Out:
# arrival_date_month
# August       0.128805
# July         0.115074
# May          0.095599
# April        0.090485
# June         0.088848
# March        0.085965
# October      0.079340
# September    0.076548
# February     0.069774
# December     0.058710
# November     0.057154
# January      0.053698
# Name: proportion, dtype: float64

# %% [markdown]
# ### **August is the most occupied (busiest) month with 12% bookings and January is the most unoccupied month with 5.36% bookings.**

# %% [markdown]
# ### **Market Segment wise bookings**

# %%
df.market_segment.value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.590622
# Offline TA/TO    0.158920
# Direct           0.135063
# Groups           0.056547
# Corporate        0.048194
# Complementary    0.008032
# Aviation         0.002597
# Undefined        0.000023
# Name: proportion, dtype: float64

# %% [markdown]
# ### Around 59% of bookings are made via Online Travel Agents, almost 15% of bookings are made via Offline Travel Agents and less than 13% are Direct bookings without any other agents.

# %% [markdown]
# ### **Year wise bookings**

# %%
df.arrival_date_year.value_counts(normalize=True)
# Out:
# arrival_date_year
# 2016    0.485045
# 2017    0.362625
# 2015    0.152330
# Name: proportion, dtype: float64

# %% [markdown]
# ### **48% bookings were done in 2016, 36% in 2017 and 15% in 2015.**

# %% [markdown]
# ### **Relative frequency distribution of meal types chosen by guests**

# %%
df.meal.value_counts(normalize=True)
# Out:
# meal
# BB           0.777816
# SC           0.108483
# HB           0.103952
# Undefined    0.005630
# FB           0.004119
# Name: proportion, dtype: float64

# %% [markdown]
# Types of meal in hotels:
# * BB - (Bed and Breakfast)
# * HB- (Half Board)
# * FB- (Full Board)
# * SC- (Self Catering)
# ### **Observation**
# ### * So the most preferred meal type by the guests is BB( Bed and Breakfast)
# ### * HB- (Half Board) and SC- (Self Catering) are equally preferred.

# %% [markdown]
# ### **Relative frequency distribution of different customer types**

# %%
df.customer_type.value_counts(normalize=True)
# Out:
# customer_type
# Transient          0.823676
# Transient-Party    0.134182
# Contract           0.035917
# Group              0.006225
# Name: proportion, dtype: float64

# %% [markdown]
# ### Transient type of customers are the more around 82%

# %% [markdown]
# ### **Reservation status by all the bookings**

# %%
df.reservation_status.value_counts(normalize=True)
# Out:
# reservation_status
# Check-Out    0.725102
# Canceled     0.263296
# No-Show      0.011602
# Name: proportion, dtype: float64

# %% [markdown]
# ### We can see 72% visitors checked out and 26% bookings were canceled

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 -  Which type of hotel is mostly prefered by the guests?

# %%
# count the occurrences of unique values in a Hotel column.
num_of_hotels=df.hotel.value_counts()

# %%
catagory_of_hotels=df.hotel.value_counts().index

# %%
plt.pie(num_of_hotels,labels=catagory_of_hotels,explode=[0.05, 0.05],shadow=True,autopct='%1.1f%%')
plt.title('Pie Chart for Most Preffered  Hotel')
# Out:
# Text(0.5, 1.0, 'Pie Chart for Most Preffered  Hotel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I chose a pie chart to visually represent the proportions of hotel preferences among guests, making it easy to see the most preferred hotel at a glance.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **1.We can see that the percent of City hotel is more compared to Resort hotel.**
#
# **2.Resort Hotel tend to be on the expensive side and most people will just stick with city hotel.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes, understanding lead times can help optimize marketing strategies and inventory management.**

# %% [markdown]
# #### Chart - 2 - How does lead time for booking vary across different arrival years, and what is the cancellation trend associated with it?

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='arrival_date_year', y='lead_time',hue='is_canceled',data= df, palette='vlag')
plt.title('Arriving year, Leadtime and Cancelations')
# Out:
# Text(0.5, 1.0, 'Arriving year, Leadtime and Cancelations')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A bar chart is chosen because it effectively displays the comparison of lead time across different arrival years, segmented by cancellation status, allowing for easy identification of trends and patterns.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **For all the 3 years, bookings with a lead time less than 90 days have fewer chances of getting canceled, and lead time more than 90 days have more chances of getting canceled.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes, identifying patterns can improve booking strategies and reduce cancellations.**

# %% [markdown]
# #### Chart - 3 - From which country the most guests are coming?

# %%
country_df = df.country.value_counts().reset_index()[:10]
country_df
# Out:
#   country  count
# 0     PRT  27453
# 1     GBR  10433
# 2     FRA   8837
# 3     ESP   7252
# 4     DEU   5387
# 5     ITA   3066
# 6     IRL   3016
# 7     BEL   2081
# 8     BRA   1995
# 9     NLD   1911

# %%
# Visualizing by  plotting the graph
plt.figure(figsize=(16,7))
sns.barplot(x=country_df['country'],y=country_df['count'],palette="bright")
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=12)
plt.title("Number of guests from diffrent Countries")
# Out:
# <ipython-input-35-ad2cfdf48a35>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_df['country'],y=country_df['count'],palette="bright")
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %% [markdown]
# Observation
#
# Most of the guests are coming from portugal i.e more than 25000 guests are from portugal
#
# abbreevations for countries-
#
#
#
# 1.   PRT- Portugal
# 2.   GBR- United Kingdom
# 3.   FRA- France
# 4.   ESP- Spain
# 5.   DEU - Germany
# 6.   ITA -Itlay
# 7.   IRL - Ireland
# 8.   BEL -Belgium
# 9.   BRA -Brazil
# 10.  NLD-Netherlands

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  **Bar plot was selected as it provides a clear comparison of the number of guests from different countries, enabling easy visualization of the top countries with the highest guest counts.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Most of the all bookings were booked from Portugal followed by Great Britain & France**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive impact can be achieved by tailoring marketing strategies to attract guests from top-contributing countries**

# %% [markdown]
# #### Chart - 4 - Cancelations

# %%
#Canceled=1, Not canceled= 0
df['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, fontsize=20)
plt.title("Cancellation and non Cancellation")
# Out:
# Text(0.5, 1.0, 'Cancellation and non Cancellation')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Pie chart was selected as it effectively visualizes the percentage distribution of canceled and non-canceled bookings, making it easy to grasp the relative proportions.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The chart shows that 72.5% of bookings were not canceled, while 27.5% were canceled, providing insight into the overall cancellation rate.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive impact is possible by understanding the cancellation rate and implementing strategies to reduce cancellations, such as offering flexible booking policies or personalized incentives.**

# %% [markdown]
# #### Chart - 5 - Analyze the distribution of preferred meal types among hotel guests

# %%
plt.figure(figsize=(14,7))
sns.countplot(x=df['meal'],palette='viridis')
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title("Preferred Meal Type")
# Out:
# <ipython-input-37-04cfcc82c075>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['meal'],palette='viridis')
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
# Types of meal in hotels:
# * BB - (Bed and Breakfast)
# * HB- (Half Board)
# * FB- (Full Board)
# * SC- (Self Catering)
# Observation
#
# So the most preferred meal type by the guests is BB( Bed and Breakfast)
#
# HB- (Half Board) and SC- (Self Catering) are equally preferred.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Count plot was selected as it effectively displays the frequency of each meal type, allowing for easy comparison and identification of the most preferred option.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The chart reveals that "Bed and Breakfast" (BB) is the most preferred meal type among guests, followed by "Half Board" (HB) and "Self Catering" (SC), which are equally popular.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Understanding guest preferences for meal plans can help tailor menu offerings and meal packages to enhance guest satisfaction and increase bookings.**

# %% [markdown]
# #### Chart - 6 - ADR relationship with total number of people

# %%
plt.figure(figsize=(20,8))
df2=df[df['total_people'] < 6]
plt.ylim(0, 500)
# plt.xlim(1,10)

sns.boxplot(x=df2['total_people'],y=df2['adr'],palette="bright")

# set lables
plt.title('ADR v/s Total Number of people')
# Out:
# <ipython-input-51-3f92382dc9c1>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df2['total_people'],y=df2['adr'],palette="bright")
# Text(0.5, 1.0, 'ADR v/s Total Number of people')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Box plot was chosen as it effectively displays the distribution of ADR across different ranges of total people, allowing for easy comparison and identification of any trends or patterns.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **as the number of people in bookings increases, the ADR also tends to increase.**

# %% [markdown]
# #### Chart - 7 - Which year had the highest bookings?

# %%
# set plot size
plt.figure(figsize=(11,7))

#  plot with countplot
sns.countplot(x=df['arrival_date_year'],hue=df['hotel'])
plt.title("Year Wise bookings")
# Out:
# Text(0.5, 1.0, 'Year Wise bookings')

# %% [markdown]
# Observation
#
# 2016 had the higest bookings.
#
# 2015 had less 7000 bookings.
#
# overall City hotels had the most of the bookings.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Count plot with hue encoding for hotel types was selected as it effectively visualizes the distribution of bookings across years and distinguishes bookings between different hotel types.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The chart reveals that 2016 had the highest number of bookings, followed by 2017 and 2015. Additionally, it shows that City hotels had the most bookings overall compared to Resort hotels across all years.**

# %% [markdown]
# #### Chart - 8 - Which distribution channel contributed more to adr in order to increase the the income.?

# %%
# group by distribution channel and hotel
distribution_channel_df=df.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()
# set plot size and plot barchart
plt.figure(figsize=(12,6))
sns.barplot(x='distribution_channel', y='adr',data=distribution_channel_df, hue='hotel',palette="colorblind")
plt.title('ADR across Distribution channel')
# Out:
# Text(0.5, 1.0, 'ADR across Distribution channel')

# %% [markdown]
# * Corporate- These are corporate hotel booing companies which makes bookings
# possible.
# * GDS-A GDS is a worldwide conduit between travel bookers and suppliers, such as hotels and other accommodation providers. It communicates live product, price and availability data to travel agents and online booking engines, and allows for automated transactions.
# * Direct- means that bookings are directly made with the respective hotels
# * TA/TO- means that booings are made through  travel agents or travel operators.
# * Undefined- Bookings are undefined. may be customers made their bookings on arrival.

# %% [markdown]
# Observation
#
#  From the plot is clear that
# 'Direct' and 'TA/TO' has almost equally contributed in adr in both type of hotels i.e. 'City Hotel' and 'Resort Hotel'.
#
# GDS has highly contributed in adr in 'City Hotel' type.
#
# GDS needs to increase Resort Hotel bookings.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Grouped bar plot was selected as it effectively compares ADR across distribution channels for both types of hotels**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The chart shows that 'Direct' and 'TA/TO' channels contribute similarly to ADR for both City and Resort hotels. However, 'GDS' significantly impacts ADR in City hotels but not in Resort hotels, suggesting an opportunity to increase GDS bookings for Resort hotels to boost revenue.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Increasing GDS bookings for Resort hotels may positively impact revenue, while neglecting this channel could result in missed revenue opportunities**

# %% [markdown]
# #### Chart - 9 - ADR across the different month.

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='arrival_date_month', y='adr', hue='hotel', data= df)
plt.show()

# %% [markdown]
# For Resort Hotel, ADR is more during june, August & december and for City Hotel, ADR is slightly more during March, April & May.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Line plot with hue encoding for hotel types was selected as it effectively displays the ADR trends over time, allowing for comparison between Resort and City hotels across months.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The chart highlights that ADR for Resort hotels peaks in June,July and August, while for City hotels, it is slightly higher in April, and Mayand June.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **If ADR fluctuations indicate negative growth during certain months, it may require adjustments to pricing or marketing strategies**

# %% [markdown]
# #### Chart - 10 - Which distribution channel has the higest cancellation rate?

# %%
canceled_df=df[df['is_canceled']==1] # 1= canceled

# group by distribution channel
canceled_df = canceled_df.groupby(['distribution_channel','hotel']).size().reset_index().rename(columns={0:'Counts'})
canceled_df

#set plot size and plot barchart
plt.figure(figsize=(12,6))
sns.barplot(x='distribution_channel',y='Counts',hue="hotel",data = canceled_df, palette="deep6")

# set labels
plt.xlabel('Distribution channel')
plt.ylabel('counts')
plt.title('Cancellation Rate Vs Distribution channel')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate Vs Distribution channel')

# %% [markdown]
# * In "TA/TO", City hotels has the high cancellation rate compared to resort
# hotels.
# * In "direct" both the hotels has almost same cancellation rate.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Grouped bar plot was selected as it effectively compares cancellation counts between distribution channels for each hotel type, for easy identification of trends and comparisons.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The chart highlights that in the "TA/TO" distribution channel, City hotels experience higher cancellation rates compared to Resort hotels, while in the "direct" and "corporate"channel, both hotel types have similar cancellation rates.**

# %% [markdown]
# #### Chart - 11 - Which distribution channel has the higest count of repeated guest?

# %%
repeated_df =df[df['is_repeated_guest']==1] # 1= canceled

# group by distribution channel
repeated_df = repeated_df.groupby(['distribution_channel','hotel']).size().reset_index().rename(columns={0:'Counts'})
repeated_df

#set plot size and plot barchart
plt.figure(figsize=(12,6))
sns.barplot(x='distribution_channel',y='Counts',hue="hotel",data = repeated_df, palette="dark6")

# set labels
plt.xlabel('Distribution channel')
plt.ylabel('Counts of Repeated Guests')
plt.title('Counts of Repeated Guests by Distribution Channel and Hotel Type')
# Out:
# Text(0.5, 1.0, 'Counts of Repeated Guests by Distribution Channel and Hotel Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Grouped bar plot (barplot with hue encoding) was chosen as it effectively compares the counts of repeated guests across distribution channels for each hotel type.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **With corporate bookings having more repeated guests in City hotels, while direct and TA/TO bookings have more repeated guests in Resort hotels.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Understanding booking patterns of repeated guests can inform targeted marketing strategies and loyalty programs, potentially increasing customer retention and revenue.**

# %% [markdown]
# #### Chart - 12 - Analyze the distribution of market segments and distribution channels in hotel bookings

# %%
plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='market_segment', data=df, palette='rocket')
plt.title('Types of market segment',fontweight="bold", size=20)

plt.subplot(1, 2, 2)
sns.countplot(data = df, x = 'distribution_channel',  palette='Set1_r')
plt.title('Types of distribution channels',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)
# Out:
# <ipython-input-44-acffb315a31f>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='market_segment', data=df, palette='rocket')
# <ipython-input-44-acffb315a31f>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df, x = 'distribution_channel',  palette='Set1_r')

# %% [markdown]
# Majority DIstribution channels and Market segment were Travel agencies wither offline/online. So better focus more on this

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Subplots with count plots were selected to visually compare the distribution of market segments and distribution channels side by side, facilitating easy comparison and identification of trends.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The charts reveal that the majority of bookings are through travel agencies, both offline and online, indicating the importance of targeting these channels for marketing efforts.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Understanding the dominant market segments and distribution channels can guide marketing strategies and resource allocation to optimize bookings.**

# %% [markdown]
# #### Chart - 13 - Analyze the distribution of guests with babies across different hotel types and their booking cancellation rates.

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='babies',hue='hotel', data=df, palette='dark')
plt.title("Number of Babies in both hotels",fontweight="bold", size=20)
plt.xlim(-0.5,2)


plt.subplot(1, 2, 2)
sns.countplot(data = df, x = 'babies', hue='is_canceled', palette='Set1_r')
plt.title('Babies vs Cancelations',fontweight="bold", size=20)
plt.xlim(-0.5,2)

plt.subplots_adjust(right=1.7)
plt.show()

# %% [markdown]
# Most visitors were arrived in pair with no children/ Babies and preferred City hotel over resort hotel
#
# visitors who had 1 or 2 children also preferred city hotel

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Count plots were chosen as they effectively display the frequency distribution of guests with babies by hotel type and cancellation status, allowing for straightforward comparison.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The charts show that most visitors arrived without babies and preferred City hotels, while those with one or two babies also favored City hotels.**

# %% [markdown]
# ### **Chart - 14 - Analyze the distribution of hotel arrivals by year and month.**

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='arrival_date_year',hue='hotel', data=df,palette='husl')
plt.title("Arrivals per year in Both hotels ",fontweight="bold", size=20)
plt.subplot(1, 2, 2)
sns.countplot(data =df, x = 'arrival_date_month',palette='husl')
plt.title('Arrivals per month',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)

plt.show()
# Out:
# <ipython-input-46-8dd753fcc2eb>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data =df, x = 'arrival_date_month',palette='husl')

# %% [markdown]
# We can see most of the bookings were in the year 2016 and bookings were doine in City hotel
#
# Most bookings were done in the month of May,June, July, August

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Dual count plots were chosen as they effectively display the frequency of arrivals across years and months, with hue encoding for hotel types to distinguish booking patterns between City and Resort hotels.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The charts reveal that 2016 had the highest bookings, predominantly in City hotels, and that bookings peak in the summer months of May, June, July, and August.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Understanding the dominant market segments and distribution channels can guide marketing strategies and resource allocation to optimize bookings.**

# %% [markdown]
# #### Chart - 15 - Correlation Heatmap

# %%
plt.figure(figsize=(16,8))
numerical_df = df.select_dtypes(include=['number'])

sns.heatmap(numerical_df.corr(),annot=True,cmap='coolwarm')
plt.title('Co-relation of the columns')
# Out:
# Text(0.5, 1.0, 'Co-relation of the columns')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **The heatmap was chosen as it effectively visualizes the correlation matrix, allowing for easy identification of relationships between multiple numerical variables.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The chart reveals the strength and direction of correlations between numerical columns, highlighting which variables are positively or negatively related to each other.**

# %% [markdown]
# #### Chart - 16 - Pair Plot

# %%
numerical_columns=['is_canceled', 'lead_time', 'days_in_waiting_list','adr','arrival_date_year']

# %%
# Create pair plot
sns.pairplot(df[numerical_columns])
plt.show()

# %% [markdown]
# - We can conclude from the relationship between lead_time and is_canceled that a longer lead time does not result in cancellations.
# - We can conclude from the lead_time and arrival_date_year graphs that people were consistently interested in booking rooms in advance in 2015, 2016, and 2017.
# - According to the graph of arrival_date_year and days_in_waiting_list, 2016 had the longest waiting period for room bookings.
# - We can conclude from the graph of ADR and days_in_waiting_list that a short minimum waiting period for bookings results in a high ADR.
# - From the graph of "is_canceled" and "days_in_waiting_list," we conclude that waiting for bookings is not a reason for booking cancellation.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Pair plot was chosen to visualize and explore relationships between multiple numerical variables simultaneously.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Longer lead times do not lead to cancellations; consistent interest in advance bookings across years; 2016 had the longest waiting period; high ADR correlates with short waiting periods; waiting periods do not cause cancellations.**

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. **Focus on City Hotels**: Given that City hotels are the most preferred and generate more revenue, consider investing in marketing, infrastructure, and service enhancements for City hotels to maximize profitability.
#
# 2. **Reduce Cancellation Rates**: Implement strategies to reduce cancellations, such as flexible cancellation policies, incentives for non-cancellable bookings, and improved communication with customers to confirm bookings.
#
# 3. **Promote Bed & Breakfast Packages**: Since BB (Bed & Breakfast) is the most preferred meal type, create and promote attractive Bed & Breakfast packages to cater to guest preferences and increase bookings.
#
# 4. **Target Portuguese Market**: With the highest number of guests coming from Portugal, tailor marketing campaigns and promotional offers specifically for the Portuguese market to further boost guest numbers from this region.
#
# 5. **Optimize Pricing for City Hotels**: Maintain or increase the average daily rate (ADR) for City hotels, as they are already generating higher revenue, but ensure the pricing remains competitive and attractive to guests.
#
# 6. **Leverage Travel Agents and Tour Operators**: Strengthen partnerships with Travel Agents/Tour Operators, as they account for 79.1% of bookings. Consider offering special deals or commission incentives to encourage more bookings through these channels.
#
# 7. **Focus on Peak Booking Year and Months**: Since most bookings occurred in 2016 and August is the busiest month, analyze the factors contributing to these peaks and replicate successful strategies in subsequent years. Plan promotions and staffing accordingly to handle the high demand in August.
#
# 8. **Cater to Couples**: Develop targeted marketing campaigns and packages for couples, as they constitute the majority of visitors. This could include romantic getaways, couple’s spa packages, and dining experiences.
#
# 9. **Seasonal Promotions**: Address the low occupancy in January by offering special promotions and discounts during this month to attract more guests and improve occupancy rates during the off-peak season.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# - City hotels are the most preferred hotel type by the guests. We can say City
#
# - hotel is the busiest hotel.
#
# - 27.5 % bookings were got cancelled out of all the bookings.One of the four reservations is canceled.
#
# - BB( Bed & Breakfast) is the most preferred type of meal by the guests.
#
# - Maximum number of guests were from Portugal, i.e. more than 25000 guests
#
# - Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.
#
# - 79.1 % bookings were made through TA/TO (travel agents/Tour operators).
#
# - Most of the bookings for City hotels and Resort hotel were happened in 2016.
#
# - Most visitors are couples.
#
# - bookings with a lead time less than 90 days have fewer chances of getting canceled, and lead time more than 90 days have more chances of getting canceled.
#
# - August is the most occupied (busiest) month with 12% bookings and January is the most unoccupied month with 5.36% bookings.
#
# - Around 59% of bookings are made via Online Travel Agents, almost 15% of bookings are made via Offline Travel Agents and less than 13% are Direct bookings without any other agents.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
